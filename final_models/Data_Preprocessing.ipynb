# %% [markdown]
# # Import tweets datasets into pandas dataframe

# %%
#Final crawled dataset
import pandas as pd
tweets = pd.read_csv('final_samsung_crawled.csv', sep= ',')
tweets.head()
#len(tweets) #45782
# Out:
#                    id              date  \
# 0  925495649730117632  2017-10-31 23:52
# 1  925490587402465280  2017-10-31 23:32
# 2  925483268715184128  2017-10-31 23:03
# 3  925476232380145664  2017-10-31 22:35
# 4  925473978625548289  2017-10-31 22:26
#
#                                                 text  \
# 0  # phone gear Anti Gravity Casing for iPhone an...
# 1  Went to the cell phone repair place and they s...
# 2  Like and Share if you want this Haunted Mansio...
# 3  Great uses for "defunct" phones. The "reuse" p...
# 4  Samsung Galaxy A5 2018 Full Phone Specificatio...
#
#                                            permalink
# 0  https://twitter.com/MyPhoneMyWorld/status/9254...
# 1  https://twitter.com/SinamonLance/status/925490...
# 2  https://twitter.com/Siresayshop/status/9254832...
# 3  https://twitter.com/cosmo_nz/status/9254762323...
# 4  https://twitter.com/entclassblog/status/925473...

# %%
#Final annotated dataset from annotation.ipynb
tweets_annoated = pd.read_csv('samsung_annotated_40k.csv') # file should be changed
tweets_annoated.head()
# Out:
#                    id                                               text  \
# 0  925495649730117632  # phone gear Anti Gravity Casing for iPhone an...
# 1  925490587402465280  Went to the cell phone repair place and they s...
# 2  925483268715184128  Like and Share if you want this Haunted Mansio...
# 3  925476232380145664  Great uses for "defunct" phones. The "reuse" p...
# 4  925473978625548289  Samsung Galaxy A5 2018 Full Phone Specificatio...
#
#    polarity  polarity_confidence subjectivity  subjectivity_confidence
# 0   neutral             0.972387    objective                 0.999999
# 1  negative             0.785670   subjective                 1.000000
# 2   neutral             0.914202   subjective                 1.000000
# 3   neutral             0.664289    objective                 0.999453
# 4   neutral             0.865111    objective                 1.000000

# %% [markdown]
# # additional features 'polarityNum' and 'brand'

# %%
for i in range(0, len(tweets_annoated)):
    if  tweets_annoated.loc[i]['polarity'] == 'positive':
        tweets_annoated.at[i, 'polarityNum'] = 1
    elif tweets_annoated.loc[i]['polarity'] == 'negative':
        tweets_annoated.at[i, 'polarityNum'] = -1
    else:
        tweets_annoated.at[i, 'polarityNum'] = 0

# %%
tweets_annoated['brand'] = 'Samsung'

# %%
tweets_annoated.head(3)
# Out:
#                    id                                               text  \
# 0  925495649730117632  # phone gear Anti Gravity Casing for iPhone an...
# 1  925490587402465280  Went to the cell phone repair place and they s...
# 2  925483268715184128  Like and Share if you want this Haunted Mansio...
#
#    polarity  polarity_confidence subjectivity  subjectivity_confidence  \
# 0   neutral             0.972387    objective                 0.999999
# 1  negative             0.785670   subjective                 1.000000
# 2   neutral             0.914202   subjective                 1.000000
#
#    polarityNum    brand
# 0          0.0  Samsung
# 1         -1.0  Samsung
# 2          0.0  Samsung

# %% [markdown]
# # Balance the dataset to mininum polarity value

# %%
tweets_annoated.polarity.value_counts()
# Out:
# neutral     18696
# negative    11670
# positive    11098
# Name: polarity, dtype: int64

# %%
g = tweets_annoated.groupby('polarity')
tweets_balanced = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))

# %%
tweets_balanced.polarity.value_counts()
# Out:
# positive    11098
# negative    11098
# neutral     11098
# Name: polarity, dtype: int64

# %%
tweets_balanced.to_csv('tweets_balanced_samsung.csv', index =False)

# %%
tweets_balanced_samsung = pd.read_csv('tweets_balanced_samsung.csv')
tweets_balanced_samsung.head(3)
# Out:
#                    id                                               text  \
# 0  971714841315438593  Oh yeah I assumed. For one thing no one could ...
# 1  920490436904607746  But out of the box are Samsung Phone OLED scre...
# 2  979000635222872064  What Huawei does with some of its phones of la...
#
#    polarity  polarity_confidence subjectivity  subjectivity_confidence  \
# 0  negative             0.998388   subjective                 1.000000
# 1  negative             0.501652   subjective                 0.995007
# 2  negative             0.957417   subjective                 1.000000
#
#    polarityNum    brand
# 0         -1.0  Samsung
# 1         -1.0  Samsung
# 2         -1.0  Samsung

# %% [markdown]
# # Data Preprocessing
# # (lower case, word tokenize,stopword removal,punctuation removal, lemmatization)

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
import codecs
import csv
import nltk
#nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

with codecs.open('samsung_balanced_11098_preprocessed.csv', 'w', 'utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['id', 'text_preprocessed','polarity','polarity_confidence','subjectivity','subjectivity_confidence','polarityNum', 'brand'])
    for i in range(len(tweets_balanced_samsung)):
        text = (tweets_balanced_samsung['text'].astype(str))[i].lower()

        stopwordSet = set(stopwords.words('english'))
        textSplit = [word for word in word_tokenize(text) if word not in stopwordSet]
        noPunc = [word for word in str(textSplit) if word not in string.punctuation]
        words = ''.join(noPunc)
        wordStem = [lemmatizer.lemmatize(word) for word in word_tokenize(words)]
        alphaOnly = [word for word in wordStem if word.isalpha()]
        wordstring = ' '.join(alphaOnly)
        writer.writerow([tweets_balanced_samsung.id[i], wordstring,tweets_balanced_samsung.polarity[i],tweets_balanced_samsung.polarity_confidence[i],tweets_balanced_samsung.subjectivity[i],tweets_balanced_samsung.subjectivity_confidence[i],tweets_balanced_samsung.polarityNum[i],tweets_balanced_samsung.brand[i]])

# %%
samsung_balanced_preprocessed = pd.read_csv('samsung_balanced_11098_preprocessed.csv')
samsung_balanced_preprocessed.head()
# Out:
#                    id                                  text_preprocessed  \
# 0  971714841315438593  oh yeah assumed one thing one could mean merce...
# 1  920490436904607746  box samsung phone oled screen great saturated ...
# 2  979000635222872064  huawei phone late crazy big brand samsung appl...
# 3  957436019636363264  scale samsung horrible make phone run worse id...
# 4  935117316827750401  m using samsung get stuck time nt mind new raz...
#
#    polarity  polarity_confidence subjectivity  subjectivity_confidence  \
# 0  negative             0.998388   subjective                 1.000000
# 1  negative             0.501652   subjective                 0.995007
# 2  negative             0.957417   subjective                 1.000000
# 3  negative             0.999960   subjective                 1.000000
# 4  negative             0.798083   subjective                 1.000000
#
#    polarityNum    brand
# 0         -1.0  Samsung
# 1         -1.0  Samsung
# 2         -1.0  Samsung
# 3         -1.0  Samsung
# 4         -1.0  Samsung

# %% [markdown]
# # Merge original crawled dataset and preprocssed to get all features

# %%
merged_samsung = pd.merge( tweets,samsung_balanced_preprocessed, on='id', how='inner')
merged_samsung.head()
# Out:
#                    id              date  \
# 0  925495649730117632  2017-10-31 23:52
# 1  925490587402465280  2017-10-31 23:32
# 2  925476232380145664  2017-10-31 22:35
# 3  925472949150380033  2017-10-31 22:22
# 4  925472766480076801  2017-10-31 22:21
#
#                                                 text  \
# 0  # phone gear Anti Gravity Casing for iPhone an...
# 1  Went to the cell phone repair place and they s...
# 2  Great uses for "defunct" phones. The "reuse" p...
# 3  damn, and with Apple breaking their iOS, samsu...
# 4  rachel: "theres not someone who owns some appl...
#
#                                            permalink  \
# 0  https://twitter.com/MyPhoneMyWorld/status/9254...
# 1  https://twitter.com/SinamonLance/status/925490...
# 2  https://twitter.com/cosmo_nz/status/9254762323...
# 3  https://twitter.com/mcdroidgame/status/9254729...
# 4  https://twitter.com/cmbxsmile/status/925472766...
#
#                                    text_preprocessed  polarity  \
# 0  phone gear anti gravity casing iphone samsung ...   neutral
# 1  went cell phone repair place said d need conta...  negative
# 2  great us defunct phone reuse part reuse reduce...   neutral
# 3  damn apple breaking io samsung overloading cra...  negative
# 4  rachel there someone owns apple product apple ...   neutral
#
#    polarity_confidence subjectivity  subjectivity_confidence  polarityNum  \
# 0             0.972387    objective                 0.999999          0.0
# 1             0.785670   subjective                 1.000000         -1.0
# 2             0.664289    objective                 0.999453          0.0
# 3             0.494093   subjective                 0.999850         -1.0
# 4             0.769667   subjective                 1.000000          0.0
#
#      brand
# 0  Samsung
# 1  Samsung
# 2  Samsung
# 3  Samsung
# 4  Samsung

# %%
merged_samsung.to_csv('samsung_final_14may.csv',index = False)

# %%
tweets_samsung = pd.read_csv('samsung_final_14may.csv')
tweets_samsung.head(3)
# Out:
#                    id              date  \
# 0  925495649730117632  2017-10-31 23:52
# 1  925490587402465280  2017-10-31 23:32
# 2  925476232380145664  2017-10-31 22:35
#
#                                        text_original  \
# 0  # phone gear Anti Gravity Casing for iPhone an...
# 1  Went to the cell phone repair place and they s...
# 2  Great uses for "defunct" phones. The "reuse" p...
#
#                                            permalink    brand  \
# 0  https://twitter.com/MyPhoneMyWorld/status/9254...  Samsung
# 1  https://twitter.com/SinamonLance/status/925490...  Samsung
# 2  https://twitter.com/cosmo_nz/status/9254762323...  Samsung
#
#                                    text_preprocessed  polarity  \
# 0  phone gear anti gravity casing iphone samsung ...   neutral
# 1  went cell phone repair place said d need conta...  negative
# 2  great us defunct phone reuse part reuse reduce...   neutral
#
#    polarity_confidence subjectivity  subjectivity_confidence  polarityNum  \
# 0             0.972387    objective                 0.999999          0.0
# 1             0.785670   subjective                 1.000000         -1.0
# 2             0.664289    objective                 0.999453          0.0
#
#    Checked
# 0        1
# 1        1
# 2        1

# %%
#same steps are followed for iphone to get the iphone final dataset
tweets_iphone = pd.read_csv('iphone_final_14may.csv')
tweets_iphone.head(3)
# Out:
#                    id              date  \
# 0  948570515085713408  2018-01-03 16:03
# 1  945970348436094977  2017-12-27 11:51
# 2  951907048035270656  2018-01-12 21:01
#
#                                        text_original  \
# 0  It's 10 AM and my iPhone 7 battery is already ...
# 1  Apple launched three phones this year: the bez...
# 2  Cut one phone completely OFF and my iPhone on ...
#
#                                            permalink  \
# 0  https://twitter.com/TheScottBeach/status/94857...
# 1  https://twitter.com/Today__Tech/status/9459703...
# 2  https://twitter.com/gods1blessings/status/9519...
#
#                                    text_preprocessed  polarity  \
# 0  s iphone battery already minute phone call tol...  negative
# 1  apple launched three phone year bezelbusting i...  positive
# 2  cut one phone completely iphone dnd yeah ready...  positive
#
#    polarity_confidence subjectivity  subjectivity_confidence  polarityNum  \
# 0             0.894631   subjective                      1.0         -1.0
# 1             0.492551   subjective                      1.0          1.0
# 2             0.355765   subjective                      1.0          1.0
#
#     brand
# 0  iphone
# 1  iphone
# 2  iphone

# %% [markdown]
# # Merging of samsung and iphone dataset to get Combined dataset

# %%
combined_final = tweets_samsung.append(tweets_iphone)
combined_final.to_csv('combined_final_14may.csv',index = False)

# %%
tweets_combined = pd.read_csv('combined_final_14may.csv')
tweets_combined.head(3)
# Out:
#    Checked    brand              date                  id  \
# 0      1.0  Samsung  2017-10-31 23:52  925495649730117632
# 1      1.0  Samsung  2017-10-31 23:32  925490587402465280
# 2      1.0  Samsung  2017-10-31 22:35  925476232380145664
#
#                                            permalink  polarity  polarityNum  \
# 0  https://twitter.com/MyPhoneMyWorld/status/9254...   neutral          0.0
# 1  https://twitter.com/SinamonLance/status/925490...  negative         -1.0
# 2  https://twitter.com/cosmo_nz/status/9254762323...   neutral          0.0
#
#    polarity_confidence subjectivity  subjectivity_confidence  \
# 0             0.972387    objective                 0.999999
# 1             0.785670   subjective                 1.000000
# 2             0.664289    objective                 0.999453
#
#                                        text_original  \
# 0  # phone gear Anti Gravity Casing for iPhone an...
# 1  Went to the cell phone repair place and they s...
# 2  Great uses for "defunct" phones. The "reuse" p...
#
#                                    text_preprocessed
# 0  phone gear anti gravity casing iphone samsung ...
# 1  went cell phone repair place said d need conta...
# 2  great us defunct phone reuse part reuse reduce...
